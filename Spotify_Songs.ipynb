# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("spotify_songs.csv")

# %%
df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
df_head_subset = df[['track_id', 'track_name', 'track_artist', 'track_popularity', 'track_album_release_date', 'playlist_genre']]
display(df_head_subset.head())
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity track_album_release_date playlist_genre
# 0        Ed Sheeran                66               2019-06-14            pop
# 1          Maroon 5                67               2019-12-13            pop
# 2      Zara Larsson                70               2019-07-05            pop
# 3  The Chainsmokers                60               2019-07-19            pop
# 4     Lewis Capaldi                69               2019-03-05            pop

# %%
df.shape
# Out:
# (32833, 23)

# %%
df['duration_ms'].describe()
# Out:
# count     32833.000000
# mean     225799.811622
# std       59834.006182
# min        4000.000000
# 25%      187819.000000
# 50%      216000.000000
# 75%      253585.000000
# max      517810.000000
# Name: duration_ms, dtype: float64

# %%
df.dtypes
# Out:
# track_id                     object
# track_name                   object
# track_artist                 object
# track_popularity              int64
# track_album_id               object
# track_album_name             object
# track_album_release_date     object
# playlist_name                object
# playlist_id                  object
# playlist_genre               object
# playlist_subgenre            object
# danceability                float64
# energy                      float64
# key                           int64
# loudness                    float64
# mode                          int64
# speechiness                 float64
# acousticness                float64
# instrumentalness            float64
# liveness                    float64
# valence                     float64
# tempo                       float64
# duration_ms                   int64
# dtype: object

# %%
sns.set()
cols = ['track_popularity', 'key']
sns.pairplot(df[cols], size = 3.5)
plt.show();
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df['track_popularity'].mean()
# Out:
# 42.477080985593766

# %%
sorted_df = df.sort_values(by='track_popularity', ascending=False)

top_20_songs = sorted_df.head(20)

top_20_songs[['track_name', 'track_artist', 'track_popularity']]
# Out:
#             track_name    track_artist  track_popularity
# 20091     Dance Monkey     Tones and I               100
# 1551      Dance Monkey     Tones and I               100
# 30202          ROXANNE  Arizona Zervas                99
# 23104          ROXANNE  Arizona Zervas                99
# 21468          ROXANNE  Arizona Zervas                99
# 20092          ROXANNE  Arizona Zervas                99
# 30209          Circles     Post Malone                98
# 19715  Blinding Lights      The Weeknd                98
# 19740          Circles     Post Malone                98
# 20252             Tusa         KAROL G                98
# 18756             Tusa         KAROL G                98
# 18330          Circles     Post Malone                98
# 19707          The Box     Roddy Ricch                98
# 19265         Memories        Maroon 5                98
# 30207         Memories        Maroon 5                98
# ...

# %%
mean_popularity = df['track_popularity'].mean()

df['popularity_results'] = np.where(df['track_popularity'] > mean_popularity, 'P', 'F')

def pie(playlist_genre):
    """This function creates a pie chart with percentages of successful songs in different categories.

    Args:
        category: str. Category name in the Spotify dataset.

    Returns:
        None
    """
    label = []
    label_percent = []

    for cat in df[playlist_genre].unique():
        label.append(cat)
        pass_cat = df[(df[playlist_genre] == cat) & (df['popularity_results'] == 'P')].shape[0]
        all_cat = df[df[playlist_genre] == cat].shape[0]
        label_percent.append(pass_cat / all_cat * 100)

    fig, axs = plt.subplots()
    axs.pie(label_percent, labels=label, autopct='%1.1f%%')
    plt.title(f"Popularity based on {playlist_genre}")
    plt.show()

# %%
pie('playlist_genre')
